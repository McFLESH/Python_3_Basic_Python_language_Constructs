# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_3_Basic_Python_language_Constructs/blob/main/3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Напишите программу, на вход которой подается строка с перечнем продуктов,
# которые нужно продвигать в социальных сетях. Перечень подаётся на вход через пробел.
s = input()
s = s.split()
for i in s:
  print(i)
